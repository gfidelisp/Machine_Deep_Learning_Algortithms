# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import copy
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sn
import scipy.io
from keras.utils import np_utils

from matplotlib import rc

import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

# %% [markdown]
# ## Funct

# %% [markdown]
# #### Função de Ativação - Sigmoide

# %%
def activation(z, act):
    """
    Função de Ativação
    
    activation (z, act)    
    
    return (func) 
    """

    # Função sigmoide
    if act == 'sig':
        func = 1/(1+np.exp(-z))

    # Função tangente hiperbólica
    elif act == 'tanh':
        func = np.tanh(z)
    
    # Função ReLU
    elif act == 'Relu':
        func = np.maximum(0,z)

    # Função softmax
    elif act == 'softmax':
        e = np.exp(z)
        func = e/sum(e)
    
    else:
        print('Erro! Função de Ativação não identificada.')

    return func

# %% [markdown]
# #### Derivada da função ReLU

# %%
def derivates(z, act, X):
    """
    Função das derivadas
    
    derivates(a, act):

    return(der)
    """
   
    # Função sigmoide
    if act == 'sig':
        a = activation(z, act)
        a = np.vstack((a,np.ones(len(X))))
        der = a*(1-a)


    # Função tangente hiperbólica
    elif act == 'tanh':
        a = activation(z, act)
        a = np.vstack((a,np.ones(len(X))))
        der = (1-a**2)

    
    # Função ReLU
    elif act == 'Relu':
        z[z<=0] = 0
        z[z>0] = 1

        der = np.vstack((z,np.ones(len(X))))

    else:
        print('Erro! Função de Ativação não identificada.')

    return der

# %% [markdown]
# #### Função Custo - Binary Cross-Entropy

# %%
def BCE(X,W,y,Neurons, act):
    """
    
    Função  Custo 
    
    BCE(X,W,y,Neurons)
    
    return -np.sum(y*np.log(h) + (1-y)*np.log(1-h))/len(y)
    
    """
    
    # Cálculo da saída da Rede Neural
    a_mat = forward_prop(X, W, Neurons, act)
    h = a_mat[-1]
    
    return -np.sum(y*np.log(h) + (1-y)*np.log(1-h))/len(y)

# %%
def CE(X,W,y,Neurons, act):
    """
    
    Função  Custo 
    
    BCE(X,W,y,Neurons)
    
    return -np.sum(y*np.log(h) + (1-y)*np.log(1-h))/len(y)
    
    """
    
    # Cálculo da saída da Rede Neural
    a_mat = forward_prop(X, W, Neurons, act)
    h = a_mat[-1]
    
    loss = -(np_utils.to_categorical(y).T*np.log(h)).sum(axis = 1)

    return loss/float(y.shape[0])

# %% [markdown]
# #### Função para o Cálculo Gradiente Numericamente

# %%
def Grad(W, X, y, Neurons, act):
    
    """
    
    Gradiente aproximado
    
    rad(W, X, y, Neurons)
    
    return Grad_aprox
    
    """
    
    # Incremento nos pesos e vieses
    Epsilon = 10**-15
    
    # Copiando o tamanho do vetor de pesos e vieses
    Grad_aprox = copy.deepcopy(W)
    
    #Iterando em cada uma das camadas, nós de entrada e nós de saída
    for i in range(len(W)):
        for j in range(np.shape(W[i])[0]):
            for k in range(np.shape(W[i])[1]):
                
                # Copiando duas listas para oos valores positivos e negativos
                W_plus = copy.deepcopy(W)
                W_minus = copy.deepcopy(W)
                
                # Adicionando os incrementos em elementos selecionados das listas
                W_plus[i][j][k] = W_plus[i][j][k] + Epsilon
                W_minus[i][j][k] = W_minus[i][j][k] - Epsilon
                
                #Cálculo do Gradiente
                Grad_aprox[i][j][k] = (BCE(X, W_plus , y, Neurons, act) - 
                                       BCE(X, W_minus, y, Neurons, act))/(2*Epsilon)
            
    return Grad_aprox

# %% [markdown]
# #### Forward Propagation

# %%
def forward_prop(X, W, Neurons, act):
    """
    
    Função Forward Propagation
    
    forward_prop(X, W)
    
    return a_mat
    
    """
    
    # a^(1) = X + 1
    a = np.vstack((np.array(X).T, np.ones(len(np.array(X)))))
    
    # Guardando o valor de a no vetor a_vec
    a_vec = copy.deepcopy(a)
    
    #Iterando em cada camada
    for c,v in enumerate(W):

        # Coletando os dados do vetor a 
        a = a_vec[-np.shape(v)[1]:]

        # z^(c) = theta^(c-1)*a^(c-1)
        z = np.dot(v,a)

        # Para toda a camada, exceto a última, adicionar um vetor 1 para a:
        if c != len(W)-1:            
            
            # Aplicando a Função de ativação 
            a = activation(z, act)
            
            # Vetor de elementos 1 a ser adicionado em a
            add_one = np.ones(np.shape(a_vec[-np.shape(v)[1]:])[1])

            # a^(c) = a^(c) + 1        
            a = np.vstack((a,add_one))
        
        else:
            # a^(c) = sigmoid(z^(c))
            a = activation(z, 'softmax')
        
        # Guardando o valor de a no vetor a_vec
        a_vec = np.vstack((a_vec,a))
    
    # Transformação da estrtura de a_vec
    a_mat = []
    for i in range(len(Neurons)):
        a_mat.append(a_vec[sum(Neurons[:i])+i:sum(Neurons[:i+1])+i+1])
    
    return a_mat

# %% [markdown]
# #### Backward Propagation

# %%
def backward_prop(a_mat, sigma, Delta, Neurons, y, W, act, X):
    """
    
    Função Backward Propagation
    
    forward_prop(a_mat, sigma, Delta, Neurons, y, W)v
    
    return Delta
    
    """   
    
    # sigma^(L) = a^(L) - y
    sigma[len(Neurons)-2] = a_mat[-1] - np_utils.to_categorical(y).T
    
    # sigma^(L-1) = W^(L-1)^T*sigma^(L)*(a^(L-1))*(1- a^(L-1))
    i = len(Neurons)-3
    sigma[i] = np.dot(W[i+1].T,sigma[i+1])*derivates(np.dot(W[i],a_mat[i]), act, X)

    # Iterando até sigma^(2)
    for i in range(len(W)-3,-1,-1):

        # sigma^(l-1) = W^(l-1)^T*sigma^(l)*(a^(l-1))*(1- a^(l-1))
        sigma[i] = np.dot(W[i+1].T,sigma[i+1][:-1])*derivates(np.dot(W[i],a_mat[i]), act, X)
    
    # Iterando até L-1
    for i in range(len(sigma)-1):
        
        # Delta^(l) = Delta^(l) + a^(l)*sigma^(l+1) 
        Delta[i] = np.dot(a_mat[i],sigma[i].T).T[:-1]/len(y)
    
    return Delta

# %% [markdown]
# #### Função de Aprendizado

# %%
def Neural_Network(alpha, it, W, X, sigma, Delta, y, Neurons, X_t, y_t, act, Silent = True, Grad_aprox = False):   
    Perf = []
    Lo   = []
    Lo_t = []
    # Iterando até um número de epísódios it    
    for iter in range(it):
        
        # Forward Propagation
        a_mat  = forward_prop(X, W, Neurons, act)
        
        # Backward Propagation
        Del = backward_prop(a_mat, sigma, Delta, Neurons, y, W, act, X)
        
        # Atualizando o valor dos pesos
        W = list(W - alpha*np.array(Del))
        
        # Impriminto a função custo ou acurácia
        acc      = np.sum(forward_prop(X, W, Neurons, act)[-1].T.argmax(axis = 1) == y.T)/len(y)*100
        acc_test = np.sum(forward_prop(X_t, W, Neurons, act)[-1].T.argmax(axis = 1) == y_t.T)/len(y_t)*100
        
        Loss      = CE(X  , W, y  , Neurons, act)
        Loss_test = CE(X_t, W, y_t, Neurons, act)
        
        Perf.append([acc, acc_test])
        Lo.append(Loss[1:])
        Lo_t.append(Loss_test[1:])
        
        if Silent == False:
            #if iter % (it/1) == 0:
            print('A acurácia na iteração '     + str(iter) + ' é de ' +str(acc))
            print('A função custo na iteração ' + str(iter) + ' é de ' +str(Loss))
        
        # Comparação entre a solução analítica e numérica do gradiente
        if Grad_aprox == True:
            if iter % (it/5) == 0:
                error = np.abs(np.array(Del) - np.array(Grad(W, X, y, Neurons, act)))
                error_deriv = np.mean([error[i].mean() for i in range(len(Neurons)-1)])
                print('Erro das derivadas: ' +str(error_deriv))
    
    accu = np.sum(forward_prop(X, W, Neurons, act)[-1].T.argmax(axis = 1) == y.T)/len(y)*100
    print('A acurácia do modelo no conjunto de treino é de ' + str(accu))
    
    cm = confusion_matrix(list(np.round(forward_prop(X_t, W, Neurons, Actv)[-1])[0]),list(y_t))
    
    return(W , Perf, Lo, Lo_t, cm)

# %% [markdown]
# ## Funções de Plotagem

# %%
def Plot_Acc(Perf, Actv, It, alpha, Neurons):
    """
    Plot da Acurácia 
    
    
    Plot_Acc(Perf, Actv, It)
    """
    
    plt.figure(figsize = (6, 6/1.618))
    plt.plot(np.array(Perf).T[0],':', label = 'Treino')
    plt.plot(np.array(Perf).T[1],'--', label = 'Teste')

    plt.grid(linestyle = ':')
    plt.legend()
    
    plt.xlabel('Episódio [-]')
    plt.ylabel('Acurácia [\%]')
    
    plt.savefig('Plots/Acurácia_'+str(Actv)+'_'+str(It)+'_' +str(alpha)+'_' + str(Neurons)+'.png', format = 'png',dpi = 600, bbox_inches = 'tight')

# %%
def Plot_Loss(Perf, Actv, It, alpha, Neurons):
    """
    Plot do Custo 
    
    
    Plot_Loss(Perf, Actv, It)
    """
    
    plt.figure(figsize = (6, 6/1.618))
    plt.plot(np.array(Perf).T[2],':', label = 'Treino')
    plt.plot(np.array(Perf).T[3],'--', label = 'Teste')
    
    plt.grid(linestyle = ':')
    plt.legend()
    
    plt.xlabel('Episódio [-]')
    plt.ylabel('Função Custo [-]')
    
    plt.savefig('Plots/Custo_'+str(Actv)+'_'+str(It)+'_' +str(alpha)+'_'+ str(Neurons) +'.png', format = 'png',dpi = 600, bbox_inches = 'tight')

# %%
def Plot_CM(cm, Actv, It, alpha, Neurons):
    
    classes = ["0", "1"]

    df_cfm = pd.DataFrame(cm, index = classes, columns = classes)
    plt.figure(figsize = (6,6/1.618))
    cfm_plot = sn.heatmap(df_cfm, annot=True)
    plt.ylabel('Valor Real')
    plt.xlabel('Valor Predito')
    cfm_plot.figure.savefig('Plots/CM_'+str(Actv)+'_'+str(It)+'_' +str(alpha)+'_'+ str(Neurons)+'.png', format = 'png',dpi = 600, bbox_inches = 'tight')

# %%
def Plot_Front(W_, Neurons, Actv, It,alpha):
    """
    Plot da Fronteira de Decisão
    
    
    Plot_Loss(Perf, Actv, It)
    """
    x_min, x_max = -1, 1.25
    xx, yy = np.meshgrid(np.linspace(x_min,x_max, 100),np.linspace(x_min, x_max, 100))
    x_in = np.c_[xx.ravel(), yy.ravel()]
    y_pred = np.round(forward_prop(x_in, W_, Neurons, Actv)[-1])
    y_pred = pd.DataFrame(y_pred.reshape(xx.shape))

    df=pd.read_csv("classification2.txt", header=None)

    X=df.iloc[:,:-1].values
    y=df.iloc[:,-1].values


    pos , neg = (y==1).reshape(len(X),1) , (y==0).reshape(len(X),1)
    
    plt.figure(figsize = (6, 6/1.618))
    plt.scatter(X[pos[:,0],0],X[pos[:,0],1],c="b",marker="+")
    plt.scatter(X[neg[:,0],0],X[neg[:,0],1],c="r",marker="o",s=10)
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdBu, alpha=0.5)

    plt.xlabel("x1 [-]")
    plt.ylabel("x2 [-]")
    plt.legend(["1","0"],loc=0)
    plt.savefig('Plots/Fronteiras_'+str(Actv)+'_'+str(It)+'_' +str(alpha)+'_'+ str(Neurons)+'.png', format = 'png',dpi = 600, bbox_inches = 'tight')

# %% [markdown]
# ### Inputs

# %%
#Data = pd.read_csv('classification2.txt', names = ['X1', 'X2', 'y'])
Data = scipy.io.loadmat('classification3.mat')

# %% [markdown]
# ### Separação dos conjunto de treino, teste e validação

# %%
X_train, X_test, y_train, y_test = train_test_split( Data['X'], 
                                                     Data['y'], 
                                                     test_size=0.2, 
                                                     random_state=42,
                                                     stratify = Data['y'])

# %% [markdown]
# ## Rede Neural

# %%
# Arquitetura da Rede
Neurons = [X_train.shape[1], 1000, 100, 11]

# Taxa de aprendizado
alpha = 1

# Númere de episódios
It = 1000

#Função de Ativação
Actv = 'Relu'

# Estruturas para guardar os dados
# Pesos
W = []

# Derivadas
Delta = []

#Erros
sigma = []


for i in range(len(Neurons)-1):

    # Xavier Initialization
    W.append(np.sqrt(6)/(Neurons[i+1] + Neurons[i])*np.random.randn(Neurons[i+1],Neurons[i]+1))
    
    Delta.append(np.zeros([Neurons[i+1],Neurons[i]+1]))
    sigma.append(np.zeros([1,1]))


# Algoritmo da Rede Neural
W_, Perf, Loss, Loss_t, cm = Neural_Network(alpha, It, W, X_train, sigma, Delta, y_train, Neurons, 
                                            X_test, y_test, Actv,Silent = False, Grad_aprox = False)
# Out:
# A acurácia na iteração 0 é de 10.0
# A função custo na iteração 0 é de [-0.          0.24137057  0.24059253  0.2382862   0.23700946  0.23769818
#   0.23992234  0.24058173  0.2395262   0.24272228  0.24019074]
# A acurácia na iteração 1 é de 10.0
# A função custo na iteração 1 é de [-0.          0.24132636  0.24053219  0.23828228  0.23696481  0.2376824
#   0.23991837  0.24055701  0.2395479   0.24274377  0.24016678]
# A acurácia na iteração 2 é de 10.0
# A função custo na iteração 2 é de [-0.          0.24131462  0.24047397  0.23827761  0.23690295  0.23767971
#   0.23993554  0.2405183   0.23955247  0.24275906  0.24013437]
# A acurácia na iteração 3 é de 10.0
# A função custo na iteração 3 é de [-0.          0.24128967  0.24041219  0.23826674  0.23685262  0.23767339
#   0.23994011  0.2404884   0.23955602  0.2427756   0.24012122]
# A acurácia na iteração 4 é de 10.0
# A função custo na iteração 4 é de [-0.          0.24126085  0.24035264  0.23825875  0.23679844  0.23768095
#   0.23994409  0.24044881  0.23956263  0.24278086  0.2401152 ]
# A acurácia na iteração 5 é de 10.0
# A função custo na iteração 5 é de [-0.          0.24126239  0.24029346  0.23825896  0.23672764  0.23768219
#   0.23998059  0.2404088   0.23955806  0.24279807  0.24006136]
# A acurácia na iteração 6 é de 10.0
# A função custo na iteração 6 é de [-0.          0.24123129  0.24023848  0.23825332  0.23667375  0.23768241
#   0.23997812  0.24037262  0.23956353  0.24280126  0.24005296]
# A acurácia na iteração 7 é de 10.0
# A função custo na iteração 7 é de [-0.          0.24121738  0.24017049  0.23822579  0.23662003  0.23766176
#   0.23998027  0.240334    0.23958595  0.24282994  0.2400346 ]
# A acurácia na iteração 8 é de 10.0
# A função custo na iteração 8 é de [-0.          0.24118959  0.24010458  0.23822119  0.23657494  0.23766871
#   0.23997724  0.24029423  0.23959958  0.242843    0.23999836]
# A acurácia na iteração 9 é de 10.0
# A função custo na iteração 9 é de [-0.          0.24115483  0.24004591  0.23820155  0.23651659  0.23767102
#   0.2399733   0.240255    0.23961582  0.24285133  0.23998749]
# A acurácia na iteração 10 é de 10.0
# A função custo na iteração 10 é de [-0.          0.24112903  0.2399745   0.23819571  0.23646121  0.23767237
#   0.23997098  0.2402237   0.23962531  0.24285702  0.23996338]
# A acurácia na iteração 11 é de 10.0
# A função custo na iteração 11 é de [-0.          0.2411032   0.23991131  0.23817433  0.23640422  0.23767019
#   0.23997502  0.24017883  0.23964053  0.24287372  0.23993388]
# A acurácia na iteração 12 é de 10.0
# A função custo na iteração 12 é de [-0.          0.24107605  0.23985443  0.23817107  0.23633785  0.23767373
#   0.23997161  0.24013722  0.23964734  0.24287247  0.23990614]
# A acurácia na iteração 13 é de 10.0
# A função custo na iteração 13 é de [-0.          0.24104973  0.23975589  0.23814194  0.23625634  0.23769897
#   0.23999302  0.24010972  0.23968411  0.24286714  0.23984907]
# A acurácia na iteração 14 é de 10.0
# A função custo na iteração 14 é de [-0.          0.2409898   0.23968822  0.23814474  0.23618852  0.23772014
#   0.23998367  0.24006699  0.23971083  0.24284567  0.23980668]
# A acurácia na iteração 15 é de 10.0
# A função custo na iteração 15 é de [-0.          0.2409407   0.23960353  0.23811451  0.23611249  0.23775391
#   0.23998091  0.24002657  0.23974687  0.24284223  0.23975873]
# A acurácia na iteração 16 é de 10.0
# A função custo na iteração 16 é de [-0.          0.24090083  0.23951134  0.23810138  0.23602235  0.23777378
#   0.23998709  0.23999207  0.23978802  0.24282862  0.23969574]
# A acurácia na iteração 17 é de 10.0
# A função custo na iteração 17 é de [-0.          0.24084649  0.23942705  0.23808243  0.23594293  0.23780359
#   0.2399818   0.23994929  0.23981388  0.24281301  0.23964777]
# A acurácia na iteração 18 é de 10.0
# A função custo na iteração 18 é de [-0.          0.24079934  0.23934821  0.23807399  0.23585415  0.23782766
#   0.23998657  0.23990228  0.23984217  0.24279723  0.23957285]
# A acurácia na iteração 19 é de 10.0
# A função custo na iteração 19 é de [-0.          0.24076056  0.23923826  0.23804456  0.235759    0.23785911
#   0.23998593  0.23986803  0.23987381  0.24279276  0.23950611]
# A acurácia na iteração 20 é de 10.0
# A função custo na iteração 20 é de [-0.          0.24070604  0.23915065  0.23803268  0.23566662  0.23788812
#   0.23998811  0.23981181  0.23990586  0.24277883  0.23941678]
# A acurácia na iteração 21 é de 10.0
# A função custo na iteração 21 é de [-0.          0.24065457  0.23905126  0.23801968  0.23556571  0.23791869
#   0.23997613  0.23977451  0.23992743  0.24276052  0.23933937]
# A acurácia na iteração 22 é de 10.0
# A função custo na iteração 22 é de [-0.          0.24060873  0.23894494  0.23799573  0.23545963  0.23795059
#   0.23998442  0.23971361  0.23996446  0.24275572  0.23923237]
# A acurácia na iteração 23 é de 10.0
# A função custo na iteração 23 é de [-0.          0.24056185  0.23883354  0.23797892  0.23534883  0.23799066
#   0.23996252  0.23969183  0.23997072  0.24273567  0.23913322]
# A acurácia na iteração 24 é de 10.0
# A função custo na iteração 24 é de [-0.          0.24051316  0.23871606  0.23795185  0.23522887  0.23802521
#   0.23996987  0.23962235  0.24000934  0.24273202  0.23900755]
# A acurácia na iteração 25 é de 10.0
# A função custo na iteração 25 é de [-0.          0.2404585   0.23860484  0.23794651  0.23510687  0.23805707
#   0.23995728  0.23955861  0.24002973  0.24271099  0.23888269]
# A acurácia na iteração 26 é de 10.0
# A função custo na iteração 26 é de [-0.          0.24040822  0.23847608  0.237918    0.23497012  0.23809711
#   0.23995996  0.23948798  0.24006458  0.24270329  0.23873692]
# A acurácia na iteração 27 é de 10.0
# A função custo na iteração 27 é de [-0.          0.24036012  0.23834885  0.23790315  0.23483551  0.23814426
#   0.23993284  0.23944445  0.24006349  0.24268557  0.23857521]
# A acurácia na iteração 28 é de 10.0
# A função custo na iteração 28 é de [-0.          0.24030629  0.23820464  0.23786988  0.23468181  0.23819238
#   0.23993429  0.23936408  0.2400938   0.24267355  0.23840443]
# A acurácia na iteração 29 é de 10.0
# A função custo na iteração 29 é de [-0.          0.24024706  0.23807112  0.23786889  0.23452157  0.23823151
#   0.23991126  0.23928292  0.24011297  0.24265714  0.23820753]
# A acurácia na iteração 30 é de 10.0
# A função custo na iteração 30 é de [-0.          0.24019255  0.23790425  0.23782485  0.23436351  0.23829184
#   0.23990752  0.2392029   0.24013242  0.24264095  0.23799401]
# A acurácia na iteração 31 é de 10.0
# A função custo na iteração 31 é de [-0.          0.24012815  0.23775677  0.23783867  0.23416646  0.23833309
#   0.23987496  0.23910742  0.24015053  0.24262555  0.23775787]
# A acurácia na iteração 32 é de 10.0
# A função custo na iteração 32 é de [-0.          0.24007262  0.23756679  0.23778609  0.23396147  0.23840465
#   0.23986328  0.23902886  0.24016107  0.24261547  0.2375094 ]
# A acurácia na iteração 33 é de 10.0
# A função custo na iteração 33 é de [-0.          0.24000431  0.23738494  0.23777861  0.23375773  0.23846126
#   0.23982707  0.23893069  0.24016795  0.2425964   0.23723401]
# A acurácia na iteração 34 é de 10.0
# A função custo na iteração 34 é de [-0.          0.23994105  0.23717634  0.23773798  0.23351036  0.23853403
#   0.23980912  0.2388279   0.24017513  0.24258823  0.23694996]
# A acurácia na iteração 35 é de 10.0
# A função custo na iteração 35 é de [-0.          0.23986205  0.23695163  0.23772825  0.23328755  0.2385961
#   0.23976765  0.23871722  0.24019028  0.24256662  0.23661574]
# A acurácia na iteração 36 é de 10.0
# A função custo na iteração 36 é de [-0.          0.23979171  0.23671136  0.23768711  0.23299403  0.23868343
#   0.23973924  0.23859623  0.24018669  0.242561    0.23627562]
# A acurácia na iteração 37 é de 10.0
# A função custo na iteração 37 é de [-0.          0.23969312  0.23645576  0.23768576  0.23270958  0.2387673
#   0.23968831  0.23845999  0.24017561  0.24254519  0.23588356]
# A acurácia na iteração 38 é de 10.0
# A função custo na iteração 38 é de [-0.          0.23960154  0.2361692   0.23767125  0.23236917  0.23887741
#   0.23963749  0.23830104  0.24016345  0.24254281  0.23543845]
# A acurácia na iteração 39 é de 10.0
# A função custo na iteração 39 é de [-0.          0.2394954   0.23586935  0.23767457  0.23202256  0.2389831
#   0.23956977  0.23813879  0.24015641  0.24253322  0.23492877]
# A acurácia na iteração 40 é de 10.0
# A função custo na iteração 40 é de [-0.          0.23939349  0.23555225  0.23766197  0.23161348  0.23910956
#   0.23950478  0.23796277  0.24012506  0.24253827  0.23438172]
# A acurácia na iteração 41 é de 10.100000000000001
# A função custo na iteração 41 é de [-0.          0.23927479  0.23521328  0.23766161  0.23119657  0.23923677
#   0.23941533  0.23779194  0.2400692   0.24254215  0.23376438]
# A acurácia na iteração 42 é de 10.5
# A função custo na iteração 42 é de [-0.          0.23916619  0.23483717  0.23761386  0.23071458  0.23938787
#   0.23933639  0.23761083  0.23998392  0.24259248  0.23311337]
# A acurácia na iteração 43 é de 11.825
# A função custo na iteração 43 é de [-0.          0.239029    0.23445496  0.23765071  0.23021064  0.2395375
#   0.23923155  0.23739142  0.23994404  0.24256305  0.23234596]
# A acurácia na iteração 44 é de 12.9
# A função custo na iteração 44 é de [-0.          0.23887562  0.23404365  0.23762346  0.22962816  0.23970907
#   0.23913314  0.23717697  0.23987935  0.24258037  0.23151043]
# A acurácia na iteração 45 é de 14.325
# A função custo na iteração 45 é de [-0.          0.23868805  0.23361357  0.23753779  0.22902847  0.23988445
#   0.23899826  0.23700678  0.23979727  0.24261618  0.2305869 ]
# A acurácia na iteração 46 é de 15.325
# A função custo na iteração 46 é de [-0.          0.23849537  0.23314223  0.23757898  0.22832462  0.24009123
#   0.23889431  0.23673091  0.23975559  0.24259613  0.22952311]
# A acurácia na iteração 47 é de 16.35
# A função custo na iteração 47 é de [-0.          0.23829953  0.23259877  0.23747812  0.22764788  0.24027236
#   0.23880174  0.2365324   0.23962681  0.2426378   0.22839161]
# A acurácia na iteração 48 é de 17.025000000000002
# A função custo na iteração 48 é de [-0.          0.23806432  0.23207982  0.23753605  0.22680517  0.2405067
#   0.23866923  0.23621867  0.23959816  0.2426092   0.22710895]
# A acurácia na iteração 49 é de 17.5
# A função custo na iteração 49 é de [-0.          0.23779328  0.23155985  0.23744523  0.22594607  0.24069915
#   0.23849292  0.23597854  0.23953416  0.24259919  0.22580401]
# A acurácia na iteração 50 é de 18.2
# A função custo na iteração 50 é de [-0.          0.23754773  0.23085026  0.23745034  0.22505761  0.24099616
#   0.23838051  0.23564401  0.2393795   0.24263186  0.22427056]
# A acurácia na iteração 51 é de 18.625
# A função custo na iteração 51 é de [-0.          0.2372371   0.23023273  0.23732794  0.22406682  0.24124538
#   0.23817908  0.23538929  0.23933292  0.24260939  0.22264596]
# A acurácia na iteração 52 é de 19.15
# A função custo na iteração 52 é de [-0.          0.23691632  0.22953302  0.23741379  0.22298539  0.24153816
#   0.23802588  0.23498485  0.23924195  0.24256143  0.22084209]
# A acurácia na iteração 53 é de 19.625
# A função custo na iteração 53 é de [-0.          0.23654019  0.22880184  0.2372173   0.22189003  0.24184813
#   0.23777547  0.23471784  0.2391216   0.242623    0.21896097]
# A acurácia na iteração 54 é de 20.200000000000003
# A função custo na iteração 54 é de [-0.          0.23614336  0.2279848   0.2372764   0.22068859  0.24216437
#   0.23763295  0.23428419  0.23901864  0.24254491  0.21682379]
# A acurácia na iteração 55 é de 20.599999999999998
# A função custo na iteração 55 é de [-0.          0.23569174  0.22718307  0.23717221  0.21942533  0.24250946
#   0.23734639  0.23392381  0.23891653  0.24255688  0.21458275]
# A acurácia na iteração 56 é de 20.974999999999998
# A função custo na iteração 56 é de [-0.          0.2352279   0.22620444  0.23713677  0.21815352  0.24285652
#   0.23719667  0.23350817  0.23873707  0.24252726  0.21214687]
# A acurácia na iteração 57 é de 21.099999999999998
# A função custo na iteração 57 é de [-0.          0.23471083  0.22537427  0.23709149  0.2166804   0.24323883
#   0.23680874  0.23306502  0.23863421  0.24253484  0.20955422]
# A acurácia na iteração 58 é de 21.3
# A função custo na iteração 58 é de [-0.          0.23411564  0.22427401  0.23703029  0.21526954  0.24361384
#   0.23662448  0.23260568  0.23848123  0.24248159  0.20674121]
# A acurácia na iteração 59 é de 21.375
# A função custo na iteração 59 é de [-0.          0.23342346  0.22329533  0.23690965  0.21372708  0.24398761
#   0.23625812  0.2321598   0.23842084  0.24239833  0.20381393]
# A acurácia na iteração 60 é de 21.7
# A função custo na iteração 60 é de [-0.          0.23277475  0.2221162   0.23685863  0.21217916  0.24440686
#   0.23597565  0.23163016  0.23817823  0.24238633  0.20061723]
# A acurácia na iteração 61 é de 21.8
# A função custo na iteração 61 é de [-0.          0.23194666  0.22103932  0.23674292  0.21052239  0.24478611
#   0.23557954  0.23114195  0.23809297  0.24223292  0.19729701]
# A acurácia na iteração 62 é de 21.875
# A função custo na iteração 62 é de [-0.          0.23113974  0.21976941  0.23663578  0.20887128  0.24521955
#   0.23522174  0.23057915  0.23784145  0.24218921  0.1937257 ]
# A acurácia na iteração 63 é de 22.2
# A função custo na iteração 63 é de [-0.          0.23018908  0.21858948  0.23653394  0.20712927  0.24559481
#   0.23477222  0.23002959  0.23768119  0.24198243  0.190019  ]
# A acurácia na iteração 64 é de 22.825
# A função custo na iteração 64 é de [-0.          0.22920071  0.21721611  0.23632745  0.20541979  0.24602358
#   0.23433938  0.22942057  0.23743401  0.24186261  0.18610319]
# A acurácia na iteração 65 é de 23.225
# A função custo na iteração 65 é de [-0.          0.22809848  0.21591722  0.23619758  0.20363831  0.24636627
#   0.2338173   0.22882252  0.23718744  0.24160284  0.18201457]
# A acurácia na iteração 66 é de 24.025
# A função custo na iteração 66 é de [-0.          0.22688401  0.2144363   0.2358955   0.20186383  0.24675964
#   0.23330039  0.22816978  0.23697261  0.24138376  0.17774969]
# A acurácia na iteração 67 é de 25.174999999999997
# A função custo na iteração 67 é de [-0.          0.22551201  0.2127999   0.23570336  0.20009486  0.24709757
#   0.23286462  0.227525    0.23666261  0.24110202  0.17328048]
# A acurácia na iteração 68 é de 26.275
# A função custo na iteração 68 é de [-0.          0.22417092  0.21135339  0.23526273  0.19819895  0.24742102
#   0.23210736  0.22678844  0.23641586  0.24077304  0.1688006 ]
# A acurácia na iteração 69 é de 27.325
# A função custo na iteração 69 é de [-0.          0.22256421  0.20955371  0.23505366  0.19640504  0.24778244
#   0.23156518  0.22606488  0.23600127  0.24038486  0.16385078]
# A acurácia na iteração 70 é de 28.249999999999996
# A função custo na iteração 70 é de [-0.          0.2209469   0.20787309  0.2344558   0.19450285  0.24804634
#   0.23067556  0.22525749  0.2356348   0.23996957  0.15919956]
# A acurácia na iteração 71 é de 29.4
# A função custo na iteração 71 é de [-0.          0.21903698  0.20553584  0.23409912  0.19293439  0.24841773
#   0.23039276  0.22452776  0.23501668  0.23945382  0.15384477]
# A acurácia na iteração 72 é de 30.0
# A função custo na iteração 72 é de [-0.          0.21732696  0.20405751  0.23339816  0.19079279  0.24861557
#   0.22897246  0.22359639  0.2344678   0.23889336  0.1490473 ]
# A acurácia na iteração 73 é de 30.9
# A função custo na iteração 73 é de [-0.          0.21529633  0.20181881  0.23251398  0.18905489  0.24874363
#   0.22808303  0.22279128  0.23375872  0.23822801  0.14417046]
# A acurácia na iteração 74 é de 31.55
# A função custo na iteração 74 é de [-0.          0.21321218  0.1998285   0.23175086  0.18711761  0.24892363
#   0.22689746  0.22178872  0.2330881   0.23754438  0.13901362]
# A acurácia na iteração 75 é de 32.275
# A função custo na iteração 75 é de [-0.          0.21093649  0.19754179  0.23083418  0.18526168  0.24900971
#   0.22580553  0.22081513  0.23226065  0.23681208  0.13397671]
# A acurácia na iteração 76 é de 32.925
# A função custo na iteração 76 é de [-0.          0.20858084  0.1954154   0.22974693  0.18341499  0.2490593
#   0.22438229  0.21977165  0.23130584  0.23594227  0.1291318 ]
# A acurácia na iteração 77 é de 33.275
# A função custo na iteração 77 é de [-0.          0.20604908  0.19307286  0.22863527  0.18156     0.24906359
#   0.22299897  0.21874788  0.23024224  0.23506745  0.12425816]
# A acurácia na iteração 78 é de 33.800000000000004
# A função custo na iteração 78 é de [-0.          0.20339366  0.19068833  0.22734792  0.17973423  0.24902434
#   0.22147134  0.21766675  0.22914267  0.23408727  0.119564  ]
# A acurácia na iteração 79 é de 34.300000000000004
# A função custo na iteração 79 é de [-0.          0.20061827  0.18828495  0.22599964  0.1778812   0.24892135
#   0.21980508  0.2165581   0.22795275  0.2331136   0.11495005]
# A acurácia na iteração 80 é de 34.9
# A função custo na iteração 80 é de [-0.          0.19772858  0.18577168  0.22451461  0.17604809  0.24876928
#   0.21805846  0.21538234  0.22670103  0.23209652  0.11054268]
# A acurácia na iteração 81 é de 35.25
# A função custo na iteração 81 é de [-0.          0.19475791  0.18334432  0.22302067  0.17420507  0.24851967
#   0.21614773  0.21412979  0.22531343  0.2309874   0.10630865]
# A acurácia na iteração 82 é de 35.449999999999996
# A função custo na iteração 82 é de [-0.          0.19166987  0.18089044  0.22141828  0.17239917  0.24820141
#   0.21415363  0.21279095  0.22386564  0.22979722  0.10228994]
# A acurácia na iteração 83 é de 35.65
# A função custo na iteração 83 é de [-0.          0.1884678   0.17848314  0.21970397  0.17063026  0.24778274
#   0.2120228   0.2113871   0.22237329  0.22854664  0.09847541]
# A acurácia na iteração 84 é de 35.85
# A função custo na iteração 84 é de [-0.          0.18515944  0.17609962  0.21788315  0.16889763  0.24725588
#   0.2098111   0.20989522  0.22085939  0.22723147  0.09486319]
# A acurácia na iteração 85 é de 36.225
# A função custo na iteração 85 é de [-0.          0.18173544  0.17377955  0.21598331  0.16721828  0.24660827
#   0.20751898  0.20828042  0.21932522  0.22583761  0.09145233]
# A acurácia na iteração 86 é de 36.95
# A função custo na iteração 86 é de [-0.          0.17819722  0.17153629  0.21397912  0.16558149  0.24582873
#   0.20512424  0.20654173  0.21773457  0.22440841  0.08830194]
# A acurácia na iteração 87 é de 38.05
# A função custo na iteração 87 é de [-0.          0.17455915  0.16936063  0.21192535  0.16400007  0.2448962
#   0.20263578  0.20466179  0.2160874   0.22293348  0.08537114]
# A acurácia na iteração 88 é de 38.824999999999996
# A função custo na iteração 88 é de [-0.          0.17084368  0.16732743  0.20976573  0.1624425   0.24381093
#   0.20004822  0.2026683   0.21437092  0.22140244  0.08266267]
# A acurácia na iteração 89 é de 39.550000000000004
# A função custo na iteração 89 é de [-0.          0.16703665  0.16537891  0.20758935  0.16096576  0.2425637
#   0.1974312   0.20050445  0.21261793  0.21980244  0.08010309]
# A acurácia na iteração 90 é de 41.125
# A função custo na iteração 90 é de [-0.          0.16318635  0.16352592  0.20523163  0.15952945  0.24118287
#   0.19474541  0.19823692  0.21090224  0.21815644  0.07771157]
# A acurácia na iteração 91 é de 42.85
# A função custo na iteração 91 é de [-0.          0.15925214  0.16178269  0.20297719  0.15814766  0.23966836
#   0.19207353  0.19583503  0.20903862  0.21641031  0.07542921]
# A acurácia na iteração 92 é de 44.5
# A função custo na iteração 92 é de [-0.          0.15529162  0.16018124  0.2005547   0.15678506  0.23803392
#   0.18930903  0.19333784  0.2071971   0.21461796  0.07333232]
# A acurácia na iteração 93 é de 46.150000000000006
# A função custo na iteração 93 é de [-0.          0.15122379  0.15868639  0.19818831  0.15545145  0.23636422
#   0.18660353  0.19074549  0.20529551  0.21265207  0.07135441]
# A acurácia na iteração 94 é de 47.55
# A função custo na iteração 94 é de [-0.          0.14717248  0.15726037  0.19566138  0.15409592  0.23465574
#   0.18389236  0.18809108  0.2034343   0.21062722  0.06951541]
# A acurácia na iteração 95 é de 48.675000000000004
# A função custo na iteração 95 é de [-0.          0.1430514   0.15591434  0.19320092  0.15276637  0.23300864
#   0.18116033  0.18541848  0.20144394  0.2084461   0.06782036]
# A acurácia na iteração 96 é de 49.95
# A função custo na iteração 96 é de [-0.          0.13891657  0.15468179  0.19068591  0.15140495  0.23132608
#   0.17843451  0.18266796  0.19955311  0.20610129  0.06625835]
# A acurácia na iteração 97 é de 51.15
# A função custo na iteração 97 é de [-0.          0.13487691  0.15350933  0.18814877  0.15000723  0.22964324
#   0.17566042  0.17981547  0.19767986  0.20372213  0.06478339]
# A acurácia na iteração 98 é de 52.15
# A função custo na iteração 98 é de [-0.          0.13088126  0.15238931  0.18552452  0.14864028  0.22784341
#   0.17294351  0.17695618  0.19586374  0.20123962  0.06339798]
# A acurácia na iteração 99 é de 52.800000000000004
# A função custo na iteração 99 é de [-0.          0.1270074   0.15142835  0.182981    0.1472438   0.22603694
#   0.170151    0.17402399  0.19389864  0.1987104   0.06207107]
# A acurácia na iteração 100 é de 53.525
# A função custo na iteração 100 é de [-0.          0.12317595  0.15043796  0.18029292  0.14588833  0.22415981
#   0.16741466  0.17107408  0.19210037  0.19612466  0.06082472]
# A acurácia na iteração 101 é de 54.1
# A função custo na iteração 101 é de [-0.          0.11943672  0.14955763  0.17765927  0.14448232  0.22225009
#   0.16463934  0.16810277  0.19029426  0.19346917  0.05964262]
# A acurácia na iteração 102 é de 54.900000000000006
# A função custo na iteração 102 é de [-0.          0.11580592  0.14868844  0.17502564  0.14306546  0.22030801
#   0.16190938  0.16510165  0.18849363  0.1907682   0.05852909]
# A acurácia na iteração 103 é de 55.60000000000001
# A função custo na iteração 103 é de [-0.          0.11229201  0.14780392  0.17234968  0.141664    0.2183696
#   0.15921199  0.16205178  0.18674461  0.18805917  0.05744059]
# A acurácia na iteração 104 é de 56.75
# A função custo na iteração 104 é de [-0.          0.10889381  0.14695641  0.16970173  0.14028289  0.21634061
#   0.15654188  0.15904692  0.18483393  0.18536521  0.05645861]
# A acurácia na iteração 105 é de 58.12500000000001
# A função custo na iteração 105 é de [-0.          0.1056358   0.14617349  0.16705931  0.13887066  0.21425682
#   0.15387332  0.15600887  0.18297291  0.18267359  0.05550266]
# A acurácia na iteração 106 é de 59.9
# A função custo na iteração 106 é de [-0.          0.1024684   0.14535267  0.16443191  0.1374517   0.21220794
#   0.15124158  0.15304211  0.181091    0.17994825  0.05459996]
# A acurácia na iteração 107 é de 61.375
# A função custo na iteração 107 é de [-0.          0.09938855  0.14447959  0.16190613  0.13600971  0.21014104
#   0.14868952  0.15011752  0.17915979  0.17720555  0.05376736]
# A acurácia na iteração 108 é de 62.575
# A função custo na iteração 108 é de [-0.          0.09646068  0.14358823  0.15934146  0.1345442   0.20803475
#   0.14611291  0.14725382  0.17726169  0.17457314  0.05296156]
# A acurácia na iteração 109 é de 64.075
# A função custo na iteração 109 é de [-0.          0.09361056  0.14269892  0.15685831  0.13309953  0.2059148
#   0.14357067  0.14446088  0.17530134  0.17192776  0.05222028]
# A acurácia na iteração 110 é de 65.35
# A função custo na iteração 110 é de [-0.          0.09085302  0.14174998  0.15447131  0.13165958  0.203787
#   0.14107318  0.14170612  0.17332947  0.16934343  0.05149736]
# A acurácia na iteração 111 é de 66.025
# A função custo na iteração 111 é de [-0.          0.08821813  0.14081654  0.1520067   0.13022531  0.20164638
#   0.13856867  0.13902212  0.17142218  0.16681623  0.0508213 ]
# A acurácia na iteração 112 é de 66.85
# A função custo na iteração 112 é de [-0.          0.08571097  0.13981469  0.14970672  0.1287478   0.19955536
#   0.13609925  0.13640068  0.16938793  0.16436026  0.05016254]
# A acurácia na iteração 113 é de 67.55
# A função custo na iteração 113 é de [-0.          0.08331116  0.13875942  0.14744584  0.12726888  0.19742373
#   0.13371302  0.13386196  0.16736541  0.16196135  0.04951318]
# A acurácia na iteração 114 é de 68.375
# A função custo na iteração 114 é de [-0.          0.08098032  0.13769481  0.14529158  0.12584239  0.19528636
#   0.13136975  0.13141734  0.16528212  0.1595559   0.04888097]
# A acurácia na iteração 115 é de 68.975
# A função custo na iteração 115 é de [-0.          0.07875385  0.13652731  0.14320948  0.12437357  0.19318881
#   0.12906777  0.12899845  0.16321306  0.15724743  0.0482953 ]
# A acurácia na iteração 116 é de 69.55
# A função custo na iteração 116 é de [-0.          0.07666524  0.13528602  0.14110413  0.12297627  0.19100899
#   0.12684024  0.12661563  0.16124558  0.15499031  0.04770743]
# A acurácia na iteração 117 é de 70.125
# A função custo na iteração 117 é de [-0.          0.07466379  0.13404009  0.13912872  0.12156858  0.18885373
#   0.12459899  0.12432439  0.15913239  0.15283226  0.04715156]
# A acurácia na iteração 118 é de 70.625
# A função custo na iteração 118 é de [-0.          0.0727394   0.13266742  0.13719448  0.1201726   0.18676536
#   0.12242403  0.12210292  0.1570485   0.15066718  0.04666545]
# A acurácia na iteração 119 é de 71.3
# A função custo na iteração 119 é de [-0.          0.07090058  0.13131567  0.13534545  0.11883538  0.18461025
#   0.12031767  0.1199425   0.15490059  0.1485535   0.04616268]
# A acurácia na iteração 120 é de 71.75
# A função custo na iteração 120 é de [-0.          0.069173    0.12995092  0.1334948   0.1174967   0.18246656
#   0.11818247  0.11784097  0.15277758  0.14654265  0.04568433]
# A acurácia na iteração 121 é de 72.375
# A função custo na iteração 121 é de [-0.          0.06748415  0.12850922  0.13173771  0.11615815  0.18037829
#   0.11609958  0.11582088  0.15064308  0.14456157  0.04523366]
# A acurácia na iteração 122 é de 72.95
# A função custo na iteração 122 é de [-0.          0.06589608  0.12703029  0.12998854  0.11485369  0.17825526
#   0.11405593  0.11387317  0.14851804  0.14267767  0.04478415]
# A acurácia na iteração 123 é de 73.32499999999999
# A função custo na iteração 123 é de [-0.          0.06436272  0.12547765  0.12833793  0.11360935  0.17609712
#   0.11209056  0.11196382  0.14644142  0.14078446  0.04435781]
# A acurácia na iteração 124 é de 73.875
# A função custo na iteração 124 é de [-0.          0.0629226   0.12394771  0.12669346  0.11236109  0.17402638
#   0.11013156  0.11010386  0.14426296  0.13900848  0.0439347 ]
# A acurácia na iteração 125 é de 74.175
# A função custo na iteração 125 é de [-0.          0.0615371   0.12233574  0.12511448  0.11114653  0.17197294
#   0.10817382  0.10832346  0.14222151  0.13718116  0.04353383]
# A acurácia na iteração 126 é de 74.575
# A função custo na iteração 126 é de [-0.          0.06024194  0.12070735  0.12351908  0.10993873  0.16996668
#   0.10621993  0.1066072   0.14014068  0.13548504  0.04314054]
# A acurácia na iteração 127 é de 74.9
# A função custo na iteração 127 é de [-0.          0.0589997   0.11899241  0.12198586  0.10876416  0.16796729
#   0.10435506  0.10497013  0.13808238  0.13378041  0.04277493]
# A acurácia na iteração 128 é de 75.25
# A função custo na iteração 128 é de [-0.          0.05780956  0.11726645  0.12053898  0.10756571  0.16598406
#   0.10250999  0.10337519  0.13601869  0.13216974  0.04241928]
# A acurácia na iteração 129 é de 75.6
# A função custo na iteração 129 é de [-0.          0.05670024  0.11565593  0.1190282   0.10639363  0.16401529
#   0.10064842  0.10183758  0.13397547  0.13060924  0.04205932]
# A acurácia na iteração 130 é de 75.875
# A função custo na iteração 130 é de [-0.          0.05558626  0.11393003  0.11758566  0.10529409  0.16206791
#   0.09891637  0.10033544  0.1319996   0.12904773  0.04170179]
# A acurácia na iteração 131 é de 76.4
# A função custo na iteração 131 é de [-0.          0.05455355  0.11226431  0.11615871  0.10418477  0.16015623
#   0.09714875  0.0989377   0.12997068  0.12756416  0.04134442]
# A acurácia na iteração 132 é de 76.6
# A função custo na iteração 132 é de [-0.          0.0535694   0.11059619  0.11477194  0.1030923   0.15827566
#   0.09542882  0.09756728  0.12796457  0.1261127   0.04100227]
# A acurácia na iteração 133 é de 76.9
# A função custo na iteração 133 é de [-0.          0.05259845  0.10889751  0.11340984  0.10208691  0.15635346
#   0.09380515  0.09624053  0.12607767  0.12462299  0.04066672]
# A acurácia na iteração 134 é de 77.25
# A função custo na iteração 134 é de [-0.          0.05170311  0.10726522  0.11210028  0.10102544  0.15453769
#   0.09212063  0.09497358  0.1240504   0.12329966  0.04034104]
# A acurácia na iteração 135 é de 77.5
# A função custo na iteração 135 é de [-0.          0.05080865  0.10558252  0.11071923  0.10007877  0.15274111
#   0.09055532  0.0937204   0.12223483  0.12189481  0.04002022]
# A acurácia na iteração 136 é de 77.725
# A função custo na iteração 136 é de [-0.          0.04998824  0.10400708  0.10943085  0.09905088  0.15102671
#   0.08894155  0.09254083  0.12022651  0.12063884  0.03971916]
# A acurácia na iteração 137 é de 77.95
# A função custo na iteração 137 é de [-0.          0.04916896  0.10234521  0.10810341  0.09814015  0.14928298
#   0.08742176  0.09133604  0.11847972  0.11939171  0.03939146]
# A acurácia na iteração 138 é de 78.05
# A função custo na iteração 138 é de [-0.          0.04840039  0.1008142   0.10690631  0.09715336  0.1476321
#   0.08589281  0.09020443  0.11649992  0.11823253  0.03909078]
# A acurácia na iteração 139 é de 78.27499999999999
# A função custo na iteração 139 é de [-0.          0.04763467  0.09922041  0.10563716  0.09627109  0.14592094
#   0.08445076  0.08908861  0.11484004  0.11702053  0.03878281]
# A acurácia na iteração 140 é de 78.475
# A função custo na iteração 140 é de [-0.          0.04692471  0.09780463  0.10444978  0.09534524  0.14433994
#   0.0829449   0.08805697  0.11294229  0.11589165  0.03848342]
# A acurácia na iteração 141 é de 78.8
# A função custo na iteração 141 é de [-0.          0.04621028  0.09627162  0.10320351  0.0945068   0.14268953
#   0.08153181  0.08704149  0.11139662  0.11475638  0.03816893]
# A acurácia na iteração 142 é de 79.14999999999999
# A função custo na iteração 142 é de [-0.          0.04554275  0.09487038  0.10201148  0.09365224  0.14112057
#   0.0801342   0.08607627  0.10963752  0.11370006  0.03789757]
# A acurácia na iteração 143 é de 79.325
# A função custo na iteração 143 é de [-0.          0.04487883  0.09344259  0.10089908  0.09281103  0.13956252
#   0.07880433  0.08510618  0.10801285  0.11265232  0.03760896]
# A acurácia na iteração 144 é de 79.475
# A função custo na iteração 144 é de [-0.          0.04425778  0.09210945  0.09969244  0.0920061   0.13804403
#   0.07748898  0.0841719   0.10643664  0.11165328  0.03731604]
# A acurácia na iteração 145 é de 79.75
# A função custo na iteração 145 é de [-0.          0.04364682  0.09083376  0.09855808  0.09122623  0.13662688
#   0.07618111  0.08329452  0.10480112  0.11064686  0.03701943]
# A acurácia na iteração 146 é de 79.85
# A função custo na iteração 146 é de [-0.          0.04303648  0.08953372  0.0974786   0.09048049  0.13515434
#   0.07494322  0.08241882  0.10335434  0.1096316   0.03672545]
# A acurácia na iteração 147 é de 79.95
# A função custo na iteração 147 é de [-0.          0.04247444  0.08836754  0.09640189  0.08969357  0.13393211
#   0.07354256  0.08164023  0.10166845  0.10874214  0.03647016]
# A acurácia na iteração 148 é de 80.05
# A função custo na iteração 148 é de [-0.          0.04188183  0.08707038  0.09532868  0.08903205  0.13238588
#   0.07246255  0.08077095  0.10049367  0.10775674  0.03617595]
# A acurácia na iteração 149 é de 80.25
# A função custo na iteração 149 é de [-0.          0.04140165  0.08605012  0.09431065  0.08821693  0.13113439
#   0.07121232  0.08004256  0.09880593  0.1069455   0.03590897]
# A acurácia na iteração 150 é de 80.5
# A função custo na iteração 150 é de [-0.          0.04087085  0.08480192  0.09320504  0.08756305  0.12979987
#   0.07009518  0.07926411  0.09771015  0.10600446  0.03562715]
# A acurácia na iteração 151 é de 80.65
# A função custo na iteração 151 é de [-0.          0.04041134  0.08383602  0.09225523  0.08681489  0.12859952
#   0.06894085  0.07856089  0.09615957  0.10516606  0.03534783]
# A acurácia na iteração 152 é de 80.75
# A função custo na iteração 152 é de [-0.          0.03992538  0.0826794   0.09120447  0.08618461  0.12730781
#   0.06789523  0.07780981  0.09508038  0.10430852  0.03507983]
# A acurácia na iteração 153 é de 80.80000000000001
# A função custo na iteração 153 é de [-0.          0.0394972   0.08177265  0.09029804  0.08546261  0.12608082
#   0.06682657  0.07715863  0.09365874  0.10350398  0.0348276 ]
# A acurácia na iteração 154 é de 80.95
# A função custo na iteração 154 é de [-0.          0.0390439   0.08073504  0.08932422  0.08486247  0.124855
#   0.06582108  0.07647198  0.09257381  0.10266575  0.03456767]
# A acurácia na iteração 155 é de 81.125
# A função custo na iteração 155 é de [-0.          0.03861717  0.07979123  0.08845832  0.08420887  0.12374435
#   0.06483623  0.0758561   0.09130737  0.10183132  0.03431919]
# A acurácia na iteração 156 é de 81.39999999999999
# A função custo na iteração 156 é de [-0.          0.03819641  0.07885252  0.08752134  0.08358119  0.12262669
#   0.06388731  0.07519832  0.09021907  0.10107681  0.03406964]
# A acurácia na iteração 157 é de 81.575
# A função custo na iteração 157 é de [-0.          0.03780133  0.07798305  0.08666897  0.08295508  0.12153189
#   0.06292647  0.07460715  0.08903392  0.10033677  0.03384744]
# A acurácia na iteração 158 é de 81.69999999999999
# A função custo na iteração 158 é de [-0.          0.03740533  0.0771129   0.08575879  0.08239549  0.12041213
#   0.06202747  0.07401292  0.08806748  0.09955647  0.03360247]
# A acurácia na iteração 159 é de 81.875
# A função custo na iteração 159 é de [-0.          0.03702111  0.07631818  0.08492376  0.08179051  0.11939847
#   0.06112591  0.07347184  0.08695196  0.09881743  0.03338574]
# A acurácia na iteração 160 é de 82.0
# A função custo na iteração 160 é de [-0.          0.03664803  0.07552548  0.08409822  0.08123182  0.11833338
#   0.06027664  0.07289489  0.0859999   0.0980896   0.03314535]
# A acurácia na iteração 161 é de 82.1
# A função custo na iteração 161 é de [-0.          0.03628591  0.07478787  0.08330841  0.08067104  0.11735019
#   0.05944234  0.07235998  0.08495273  0.09737331  0.0329304 ]
# A acurácia na iteração 162 é de 82.19999999999999
# A função custo na iteração 162 é de [-0.          0.03592295  0.074036    0.08252235  0.08012102  0.11636253
#   0.05863295  0.07180009  0.08401906  0.0967332   0.0327056 ]
# A acurácia na iteração 163 é de 82.3
# A função custo na iteração 163 é de [-0.          0.03558931  0.07332103  0.08172731  0.07957924  0.1154069
#   0.05781911  0.07128136  0.08310885  0.09610085  0.03248533]
# A acurácia na iteração 164 é de 82.35
# A função custo na iteração 164 é de [-0.          0.03523836  0.07264892  0.0810065   0.0790667   0.11445283
#   0.05706661  0.07077736  0.08217609  0.09543874  0.03227529]
# A acurácia na iteração 165 é de 82.375
# A função custo na iteração 165 é de [-0.          0.03492757  0.07198361  0.08025066  0.07850485  0.11357255
#   0.05629876  0.0702754   0.08130243  0.09485708  0.03206354]
# A acurácia na iteração 166 é de 82.45
# A função custo na iteração 166 é de [-0.          0.03461712  0.07134156  0.07954642  0.07798872  0.11263438
#   0.05558575  0.06980172  0.08048762  0.09421555  0.03185855]
# A acurácia na iteração 167 é de 82.55
# A função custo na iteração 167 é de [-0.          0.0343137   0.07073458  0.0788207   0.0775057   0.11179256
#   0.05488463  0.06932992  0.07960148  0.09362614  0.03165853]
# A acurácia na iteração 168 é de 82.65
# A função custo na iteração 168 é de [-0.          0.03401416  0.07013321  0.0781217   0.07704033  0.11093437
#   0.05419153  0.0688845   0.07881576  0.09300859  0.03146022]
# A acurácia na iteração 169 é de 82.69999999999999
# A função custo na iteração 169 é de [-0.          0.03372216  0.0695509   0.07744843  0.07657375  0.11010922
#   0.05350614  0.06843353  0.0780664   0.09240807  0.03126555]
# A acurácia na iteração 170 é de 82.8
# A função custo na iteração 170 é de [-0.          0.03344094  0.06899481  0.07679878  0.07609659  0.1093008
#   0.05286141  0.06800664  0.07729486  0.09182801  0.03107734]
# A acurácia na iteração 171 é de 82.825
# A função custo na iteração 171 é de [-0.          0.03316075  0.06842551  0.07614307  0.07565295  0.10849794
#   0.05225201  0.06756899  0.07657926  0.09127365  0.03089162]
# A acurácia na iteração 172 é de 82.975
# A função custo na iteração 172 é de [-0.          0.0328904   0.06792652  0.07549858  0.07518874  0.10775332
#   0.0516346   0.06716381  0.07582821  0.09072798  0.03070453]
# A acurácia na iteração 173 é de 83.025
# A função custo na iteração 173 é de [-0.          0.03262599  0.06739996  0.07485295  0.07476433  0.10698703
#   0.05104806  0.06676001  0.07518812  0.0901608   0.03052166]
# A acurácia na iteração 174 é de 83.075
# A função custo na iteração 174 é de [-0.          0.03238042  0.06692905  0.07427146  0.0743156   0.10625254
#   0.05045613  0.06637637  0.07444845  0.0896476   0.03034221]
# A acurácia na iteração 175 é de 83.15
# A função custo na iteração 175 é de [-0.          0.03213184  0.06644782  0.07368568  0.07389298  0.10549826
#   0.04989302  0.0660022   0.07384418  0.08908937  0.03015816]
# A acurácia na iteração 176 é de 83.3
# A função custo na iteração 176 é de [-0.          0.0319075   0.066001    0.07312816  0.07344233  0.10477841
#   0.04936737  0.06562115  0.07315833  0.08860221  0.02997065]
# A acurácia na iteração 177 é de 83.325
# A função custo na iteração 177 é de [-0.          0.0316803   0.06556269  0.0725431   0.07306032  0.10407926
#   0.0488287   0.06524116  0.07253932  0.08809238  0.02978989]
# A acurácia na iteração 178 é de 83.375
# A função custo na iteração 178 é de [-0.          0.03145627  0.06513193  0.07199822  0.07267183  0.10337375
#   0.04833976  0.06487148  0.07192968  0.08757531  0.02961074]
# A acurácia na iteração 179 é de 83.42500000000001
# A função custo na iteração 179 é de [-0.          0.03123193  0.06472476  0.07148334  0.07223781  0.10273781
#   0.04781959  0.06452023  0.07132237  0.08708343  0.02943869]
# A acurácia na iteração 180 é de 83.475
# A função custo na iteração 180 é de [-0.          0.03100773  0.06431392  0.0709536   0.07184841  0.10211461
#   0.04732001  0.0641801   0.07076819  0.08655514  0.02927566]
# A acurácia na iteração 181 é de 83.625
# A função custo na iteração 181 é de [-0.          0.03081397  0.06391028  0.07044411  0.0714444   0.10142507
#   0.04687493  0.06381767  0.07021196  0.08612097  0.0291046 ]
# A acurácia na iteração 182 é de 83.775
# A função custo na iteração 182 é de [-0.          0.03060907  0.06354847  0.06993832  0.0710689   0.1007826
#   0.04641915  0.06350145  0.06964024  0.08563472  0.02894567]
# A acurácia na iteração 183 é de 83.8
# A função custo na iteração 183 é de [-0.          0.03039716  0.063186    0.06942575  0.07068017  0.10019455
#   0.04596366  0.06318668  0.06908982  0.08518216  0.02879056]
# A acurácia na iteração 184 é de 83.89999999999999
# A função custo na iteração 184 é de [-0.          0.03019448  0.06281244  0.06894739  0.07030374  0.09956666
#   0.04553422  0.06285785  0.06858914  0.08475137  0.02863309]
# A acurácia na iteração 185 é de 83.95
# A função custo na iteração 185 é de [-0.          0.03000857  0.06247396  0.06851834  0.06991281  0.098986
#   0.04508544  0.06255296  0.06801441  0.08433793  0.02847598]
# A acurácia na iteração 186 é de 83.975
# A função custo na iteração 186 é de [-0.          0.02981392  0.06212549  0.06804127  0.06957713  0.09836452
#   0.04467055  0.06224116  0.06757501  0.08388515  0.02832643]
# A acurácia na iteração 187 é de 84.025
# A função custo na iteração 187 é de [-0.          0.02963082  0.06182639  0.0676078   0.06922263  0.09780018
#   0.04428613  0.06195711  0.06702812  0.08342759  0.02816229]
# A acurácia na iteração 188 é de 84.125
# A função custo na iteração 188 é de [-0.          0.02944705  0.06151468  0.06713921  0.06887428  0.09721462
#   0.04389975  0.06164158  0.0665967   0.08300856  0.02801333]
# A acurácia na iteração 189 é de 84.2
# A função custo na iteração 189 é de [-0.          0.02928111  0.06120066  0.0667072   0.06849714  0.09670153
#   0.0435267   0.06136027  0.0660693   0.0826095   0.02786762]
# A acurácia na iteração 190 é de 84.25
# A função custo na iteração 190 é de [-0.          0.02909427  0.06088557  0.06628251  0.06816579  0.09615587
#   0.04315453  0.06108297  0.06565187  0.08216345  0.02772442]
# A acurácia na iteração 191 é de 84.325
# A função custo na iteração 191 é de [-0.          0.02892175  0.0605945   0.06588077  0.06781219  0.09563256
#   0.04279911  0.06080848  0.06517163  0.08176569  0.02758193]
# A acurácia na iteração 192 é de 84.425
# A função custo na iteração 192 é de [-0.          0.02876021  0.06030901  0.06546916  0.06746971  0.09509102
#   0.04245427  0.06053253  0.06474866  0.08137273  0.02743343]
# A acurácia na iteração 193 é de 84.5
# A função custo na iteração 193 é de [-0.          0.02860828  0.06001668  0.0650729   0.06715139  0.09454769
#   0.04211295  0.0602732   0.06433962  0.08095576  0.02729935]
# A acurácia na iteração 194 é de 84.52499999999999
# A função custo na iteração 194 é de [-0.          0.02846032  0.05975004  0.0646746   0.06680546  0.09403625
#   0.04175798  0.06001064  0.06393432  0.08058521  0.02716322]
# A acurácia na iteração 195 é de 84.625
# A função custo na iteração 195 é de [-0.          0.02831436  0.05947092  0.06430128  0.06646602  0.09352904
#   0.041424    0.05974957  0.0635279   0.0802349   0.02702055]
# A acurácia na iteração 196 é de 84.65
# A função custo na iteração 196 é de [-0.          0.02816123  0.05922769  0.0639211   0.06614851  0.09304154
#   0.0410919   0.05951064  0.06312181  0.0798368   0.02689428]
# A acurácia na iteração 197 é de 84.65
# A função custo na iteração 197 é de [-0.          0.02800958  0.0589449   0.06355703  0.06582571  0.09254023
#   0.04079039  0.05924757  0.06278141  0.07946898  0.02675967]
# A acurácia na iteração 198 é de 84.7
# A função custo na iteração 198 é de [-0.          0.02786512  0.05872682  0.06318377  0.06550106  0.09208002
#   0.04047396  0.05902333  0.06238245  0.07907589  0.02663394]
# A acurácia na iteração 199 é de 84.725
# A função custo na iteração 199 é de [-0.          0.02772772  0.05847034  0.06283626  0.06520654  0.0915819
#   0.04016835  0.05877643  0.06204693  0.0786935   0.02651334]
# A acurácia na iteração 200 é de 84.775
# A função custo na iteração 200 é de [-0.          0.02760285  0.05823504  0.06252945  0.0648606   0.09111446
#   0.03986227  0.05853813  0.06163456  0.07838238  0.02638891]
# A acurácia na iteração 201 é de 84.8
# A função custo na iteração 201 é de [-0.          0.02746848  0.05799015  0.06216987  0.06457535  0.09065363
#   0.03957275  0.05830649  0.06132475  0.07799771  0.02626647]
# A acurácia na iteração 202 é de 84.875
# A função custo na iteração 202 é de [-0.          0.02733936  0.05777002  0.06184521  0.06426181  0.09022109
#   0.03928889  0.05809163  0.06095578  0.07763352  0.02614405]
# A acurácia na iteração 203 é de 84.925
# A função custo na iteração 203 é de [-0.          0.02720912  0.05754864  0.06151728  0.06396567  0.08976855
#   0.03902374  0.05787337  0.06062156  0.07727066  0.02602431]
# A acurácia na iteração 204 é de 84.95
# A função custo na iteração 204 é de [-0.          0.02709104  0.05730889  0.06120078  0.0636709   0.08931351
#   0.03877099  0.0576477   0.06029044  0.07694675  0.02589841]
# A acurácia na iteração 205 é de 85.0
# A função custo na iteração 205 é de [-0.          0.02696699  0.05709626  0.06088575  0.06337137  0.08888663
#   0.03850595  0.05744079  0.05995481  0.07661194  0.02577845]
# A acurácia na iteração 206 é de 84.975
# A função custo na iteração 206 é de [-0.          0.02684237  0.05687914  0.06057277  0.06308314  0.08845862
#   0.03824876  0.05723425  0.05963831  0.07626943  0.02567307]
# A acurácia na iteração 207 é de 85.02499999999999
# A função custo na iteração 207 é de [-0.          0.02672247  0.05668045  0.06027834  0.06279297  0.08804444
#   0.0380005   0.05704391  0.05929929  0.07591461  0.02556349]
# A acurácia na iteração 208 é de 85.175
# A função custo na iteração 208 é de [-0.          0.02661392  0.0564807   0.05997669  0.06250215  0.08759539
#   0.0377565   0.05683278  0.05902608  0.07558365  0.02545374]
# A acurácia na iteração 209 é de 85.175
# A função custo na iteração 209 é de [-0.          0.02649976  0.05629125  0.05971391  0.06219165  0.08721023
#   0.03751783  0.0566469   0.05865349  0.07527407  0.02534259]
# A acurácia na iteração 210 é de 85.2
# A função custo na iteração 210 é de [-0.          0.02638472  0.05609867  0.05941582  0.06193862  0.08677332
#   0.03728361  0.05644005  0.05838852  0.07494076  0.0252352 ]
# A acurácia na iteração 211 é de 85.225
# A função custo na iteração 211 é de [-0.          0.02627868  0.05592714  0.05914894  0.06165381  0.08642438
#   0.03703303  0.05626883  0.05801139  0.07461492  0.02513218]
# A acurácia na iteração 212 é de 85.275
# A função custo na iteração 212 é de [-0.          0.02616098  0.05570927  0.05882206  0.06140289  0.08600396
#   0.03683136  0.05607763  0.05781427  0.07428213  0.02501791]
# A acurácia na iteração 213 é de 85.32499999999999
# A função custo na iteração 213 é de [-0.          0.02605858  0.05555491  0.05858926  0.06108273  0.08566602
#   0.03659899  0.05591333  0.0574192   0.07399223  0.02491164]
# A acurácia na iteração 214 é de 85.35000000000001
# A função custo na iteração 214 é de [-0.          0.02594712  0.0553283   0.05828111  0.06088079  0.08523424
#   0.03639543  0.05570269  0.05724056  0.0736707   0.02480707]
# A acurácia na iteração 215 é de 85.3
# A função custo na iteração 215 é de [-0.          0.0258609   0.05519958  0.05806172  0.06054599  0.0848681
#   0.03617316  0.05553014  0.05684567  0.07342522  0.02471211]
# A acurácia na iteração 216 é de 85.39999999999999
# A função custo na iteração 216 é de [-0.          0.02574971  0.05499323  0.05777052  0.06031137  0.08449701
#   0.03596923  0.05534865  0.05664397  0.07310148  0.02460387]
# A acurácia na iteração 217 é de 85.45
# A função custo na iteração 217 é de [-0.          0.0256596   0.05482775  0.05753186  0.06001284  0.08415016
#   0.03576021  0.05519728  0.0563308   0.07281154  0.02450605]
# A acurácia na iteração 218 é de 85.5
# A função custo na iteração 218 é de [-0.          0.02555927  0.05463803  0.05724801  0.05979208  0.08378246
#   0.03557009  0.05503468  0.05611808  0.0724628   0.02441223]
# A acurácia na iteração 219 é de 85.575
# A função custo na iteração 219 é de [-0.          0.02547529  0.05446704  0.05702904  0.0595004   0.08342179
#   0.03539319  0.05486236  0.05581428  0.07219977  0.0243147 ]
# A acurácia na iteração 220 é de 85.6
# A função custo na iteração 220 é de [-0.          0.0253747   0.05429785  0.05677793  0.05926901  0.0830632
#   0.03520681  0.05469581  0.05557045  0.07188891  0.02422202]
# A acurácia na iteração 221 é de 85.675
# A função custo na iteração 221 é de [-0.          0.0252855   0.05414397  0.05654744  0.05900489  0.08271653
#   0.03502513  0.05452845  0.05530749  0.07159759  0.02412653]
# A acurácia na iteração 222 é de 85.675
# A função custo na iteração 222 é de [-0.          0.02519965  0.05398098  0.05628184  0.05876226  0.08238713
#   0.0348389   0.05436061  0.05507562  0.07130927  0.02403059]
# A acurácia na iteração 223 é de 85.675
# A função custo na iteração 223 é de [-0.          0.02511933  0.05383851  0.05605103  0.05851499  0.08204187
#   0.03464828  0.05420656  0.05480871  0.0710253   0.02394336]
# A acurácia na iteração 224 é de 85.725
# A função custo na iteração 224 é de [-0.          0.02503078  0.05368192  0.05579605  0.05828158  0.08172174
#   0.03447123  0.05403289  0.05459544  0.07073813  0.02384552]
# A acurácia na iteração 225 é de 85.75
# A função custo na iteração 225 é de [-0.          0.02495049  0.05352908  0.05557798  0.05801762  0.08139682
#   0.03430719  0.05386693  0.05435084  0.07047428  0.02374817]
# A acurácia na iteração 226 é de 85.8
# A função custo na iteração 226 é de [-0.          0.02488426  0.05337539  0.05533802  0.05774876  0.08105184
#   0.03414987  0.05368073  0.05411437  0.07027787  0.02364897]
# A acurácia na iteração 227 é de 85.9
# A função custo na iteração 227 é de [-0.          0.02479862  0.05322823  0.05510366  0.05751696  0.08072802
#   0.03399659  0.05352912  0.05388753  0.07000037  0.02355649]
# A acurácia na iteração 228 é de 85.925
# A função custo na iteração 228 é de [-0.          0.0247124   0.05309048  0.05488923  0.05726151  0.08042006
# ...
#   0.01226401  0.01988876  0.01873709  0.02403915  0.0084861 ]
# A acurácia na iteração 925 é de 94.675
# A função custo na iteração 925 é de [-0.          0.01215129  0.02525018  0.02455431  0.02033111  0.02692401
#   0.01225694  0.01987678  0.01871313  0.02402115  0.00847642]
# A acurácia na iteração 926 é de 94.675
# A função custo na iteração 926 é de [-0.          0.01214227  0.0252318   0.02453078  0.02032107  0.02690292
#   0.01224436  0.01986049  0.01869834  0.02400343  0.00847025]
# A acurácia na iteração 927 é de 94.675
# A função custo na iteração 927 é de [-0.          0.01213641  0.02521039  0.02450815  0.02031133  0.02687279
#   0.01223591  0.01984267  0.01869277  0.02398736  0.00845855]
# A acurácia na iteração 928 é de 94.675
# A função custo na iteração 928 é de [-0.          0.01213052  0.02519409  0.02451142  0.02028716  0.02684542
#   0.01222489  0.01983009  0.01865338  0.02397657  0.00845376]
# A acurácia na iteração 929 é de 94.675
# A função custo na iteração 929 é de [-0.          0.01211831  0.02517086  0.02448349  0.020291    0.02681081
#   0.01222099  0.01980982  0.01866104  0.02394834  0.00844371]
# A acurácia na iteração 930 é de 94.675
# A função custo na iteração 930 é de [-0.          0.01211064  0.02516046  0.02447709  0.02027109  0.02678376
#   0.0122083   0.01979779  0.01862638  0.02393499  0.00843908]
# A acurácia na iteração 931 é de 94.675
# A função custo na iteração 931 é de [-0.          0.01210655  0.02512877  0.02444756  0.02025916  0.02676481
#   0.01220479  0.01977699  0.01862267  0.0239215   0.00842837]
# A acurácia na iteração 932 é de 94.72500000000001
# A função custo na iteração 932 é de [-0.          0.01209765  0.02511644  0.02445253  0.02023772  0.02672836
#   0.01219343  0.01977106  0.01858558  0.0239062   0.00842361]
# A acurácia na iteração 933 é de 94.72500000000001
# A função custo na iteração 933 é de [-0.          0.01208827  0.0250943   0.02442963  0.020233    0.02670288
#   0.01218413  0.0197458   0.01858669  0.0238851   0.00841448]
# A acurácia na iteração 934 é de 94.72500000000001
# A função custo na iteração 934 é de [-0.          0.01208162  0.02508276  0.02442283  0.02021498  0.02667719
#   0.01217214  0.01973319  0.01854629  0.02387523  0.00841015]
# A acurácia na iteração 935 é de 94.72500000000001
# A função custo na iteração 935 é de [-0.          0.01207618  0.02504844  0.02439741  0.02020244  0.02664917
#   0.01216659  0.01971573  0.0185549   0.02386104  0.00839675]
# A acurácia na iteração 936 é de 94.72500000000001
# A função custo na iteração 936 é de [-0.          0.01206755  0.02504217  0.02439046  0.02018377  0.02662941
#   0.0121493   0.01970363  0.01851975  0.02384286  0.00839206]
# A acurácia na iteração 937 é de 94.72500000000001
# A função custo na iteração 937 é de [-0.          0.01205697  0.02501728  0.02436919  0.0201811   0.02660801
#   0.01214294  0.01968646  0.01850635  0.02382418  0.00838121]
# A acurácia na iteração 938 é de 94.75
# A função custo na iteração 938 é de [-0.          0.01205108  0.02498972  0.02437746  0.02014889  0.02656848
#   0.01213571  0.01967708  0.01848018  0.02381958  0.0083784 ]
# A acurácia na iteração 939 é de 94.75
# A função custo na iteração 939 é de [-0.          0.01204406  0.02496825  0.02433798  0.02014784  0.02655042
#   0.01212638  0.01965492  0.01848543  0.02379691  0.00836739]
# A acurácia na iteração 940 é de 94.75
# A função custo na iteração 940 é de [-0.          0.01203352  0.02496243  0.02433643  0.02013487  0.02652387
#   0.01211073  0.01964332  0.01845178  0.02377439  0.0083614 ]
# A acurácia na iteração 941 é de 94.75
# A função custo na iteração 941 é de [-0.          0.0120265   0.02493665  0.024312    0.02011644  0.02650668
#   0.01210196  0.01962788  0.01843847  0.02376665  0.00835272]
# A acurácia na iteração 942 é de 94.75
# A função custo na iteração 942 é de [-0.          0.01202025  0.02491508  0.02431475  0.0200996   0.0264681
#   0.01209437  0.0196114   0.01841872  0.02375169  0.00834554]
# A acurácia na iteração 943 é de 94.75
# A função custo na iteração 943 é de [-0.          0.01201195  0.02488456  0.0242774   0.02009581  0.02644439
#   0.01208652  0.01959382  0.01842557  0.0237362   0.00833669]
# A acurácia na iteração 944 é de 94.75
# A função custo na iteração 944 é de [-0.          0.01200886  0.02487593  0.02428618  0.02006683  0.02642522
#   0.01207685  0.01958155  0.01837276  0.02372325  0.0083292 ]
# A acurácia na iteração 945 é de 94.75
# A função custo na iteração 945 é de [-0.          0.01199716  0.02485121  0.02425475  0.02006718  0.0263932
#   0.0120667   0.0195677   0.01837933  0.02370206  0.00832117]
# A acurácia na iteração 946 é de 94.75
# A função custo na iteração 946 é de [-0.          0.01199466  0.02483572  0.02425791  0.02004038  0.0263678
#   0.01205899  0.01955115  0.01834428  0.02369006  0.00831358]
# A acurácia na iteração 947 é de 94.75
# A função custo na iteração 947 é de [-0.          0.01198275  0.02480861  0.02422787  0.0200405   0.0263474
#   0.0120512   0.01953325  0.01834361  0.02366853  0.00830494]
# A acurácia na iteração 948 é de 94.75
# A função custo na iteração 948 é de [-0.          0.01197828  0.02479804  0.02421667  0.02002033  0.02631864
#   0.01203688  0.0195203   0.01831846  0.02365875  0.00829666]
# A acurácia na iteração 949 é de 94.75
# A função custo na iteração 949 é de [-0.          0.01197214  0.02476996  0.02420293  0.02000902  0.026297
#   0.01203115  0.01950303  0.01830099  0.02364278  0.00828853]
# A acurácia na iteração 950 é de 94.77499999999999
# A função custo na iteração 950 é de [-0.          0.01196184  0.02475525  0.02418288  0.01999691  0.02627567
#   0.01201933  0.01949046  0.01828137  0.02362594  0.00828237]
# A acurácia na iteração 951 é de 94.77499999999999
# A função custo na iteração 951 é de [-0.          0.0119559   0.02473815  0.02416766  0.0199856   0.0262476
#   0.01200841  0.01946959  0.0182711   0.02361065  0.00827217]
# A acurácia na iteração 952 é de 94.77499999999999
# A função custo na iteração 952 é de [-0.          0.0119477   0.02471145  0.02415675  0.01996549  0.0262246
#   0.01200108  0.01945792  0.01824365  0.02360509  0.00826803]
# A acurácia na iteração 953 é de 94.77499999999999
# A função custo na iteração 953 é de [-0.          0.0119377   0.02469443  0.0241401   0.01995994  0.02620008
#   0.01198946  0.01944299  0.01823641  0.0235784   0.00825733]
# A acurácia na iteração 954 é de 94.8
# A função custo na iteração 954 é de [-0.          0.01193253  0.02466989  0.02413117  0.01993541  0.02617312
#   0.01198209  0.01942648  0.01821014  0.02357809  0.00825329]
# A acurácia na iteração 955 é de 94.8
# A função custo na iteração 955 é de [-0.          0.01192034  0.02465707  0.02411251  0.01993146  0.02614613
#   0.01196902  0.01941051  0.0182053   0.02354979  0.00824554]
# A acurácia na iteração 956 é de 94.8
# A função custo na iteração 956 é de [-0.          0.01191762  0.02463479  0.02408737  0.0199147   0.02613343
#   0.01196056  0.01939523  0.0181818   0.02354501  0.00823293]
# A acurácia na iteração 957 é de 94.8
# A função custo na iteração 957 é de [-0.          0.01190651  0.02461358  0.02408905  0.01990605  0.02609855
#   0.01195022  0.01938505  0.01816465  0.02351854  0.00822706]
# A acurácia na iteração 958 é de 94.8
# A função custo na iteração 958 é de [-0.          0.01189955  0.0245947   0.0240677   0.01988879  0.02607817
#   0.01194004  0.01936436  0.01815017  0.02351187  0.0082199 ]
# A acurácia na iteração 959 é de 94.825
# A função custo na iteração 959 é de [-0.          0.01189059  0.02457081  0.02406598  0.01987289  0.02605422
#   0.01193219  0.01935752  0.01812585  0.02348992  0.00821161]
# A acurácia na iteração 960 é de 94.85
# A função custo na iteração 960 é de [-0.          0.01187821  0.02456355  0.02402664  0.01987237  0.02603544
#   0.0119161   0.01933557  0.01813015  0.02346685  0.00820319]
# A acurácia na iteração 961 é de 94.85
# A função custo na iteração 961 é de [-0.          0.01187816  0.02454015  0.02403597  0.01984237  0.02601512
#   0.01191011  0.01932454  0.01808162  0.02346336  0.00819316]
# A acurácia na iteração 962 é de 94.85
# A função custo na iteração 962 é de [-0.          0.01186772  0.0245103   0.02401725  0.01983207  0.02597659
#   0.01190215  0.01930724  0.01809414  0.02344602  0.00818782]
# A acurácia na iteração 963 é de 94.85
# A função custo na iteração 963 é de [-0.          0.01185961  0.02449789  0.02400143  0.01982202  0.02596585
#   0.01189033  0.019296    0.01805845  0.02342725  0.00817959]
# A acurácia na iteração 964 é de 94.85
# A função custo na iteração 964 é de [-0.          0.01185234  0.02447534  0.02399172  0.01980439  0.02593191
#   0.0118816   0.01927866  0.01805235  0.02341619  0.00817107]
# A acurácia na iteração 965 é de 94.875
# A função custo na iteração 965 é de [-0.          0.01184153  0.02446796  0.02395934  0.01980306  0.02592358
#   0.01186587  0.01926132  0.01803695  0.02339225  0.00816121]
# A acurácia na iteração 966 é de 94.875
# A função custo na iteração 966 é de [-0.          0.01183831  0.0244412   0.02396186  0.01977786  0.02588932
#   0.01186172  0.01924478  0.01800843  0.02339048  0.00815642]
# A acurácia na iteração 967 é de 94.875
# A função custo na iteração 967 é de [-0.          0.01182811  0.02442074  0.02394373  0.01976081  0.02587296
#   0.01184927  0.01923896  0.01799279  0.02336951  0.00815086]
# A acurácia na iteração 968 é de 94.875
# A função custo na iteração 968 é de [-0.          0.01182233  0.02439363  0.02393551  0.01974289  0.025834
#   0.0118435   0.0192181   0.0179902   0.02336163  0.00814358]
# A acurácia na iteração 969 é de 94.875
# A função custo na iteração 969 é de [-0.          0.01180936  0.02439274  0.02390497  0.01974266  0.02582883
#   0.01182423  0.01920919  0.01796462  0.02333255  0.00813399]
# A acurácia na iteração 970 é de 94.875
# A função custo na iteração 970 é de [-0.          0.01180492  0.02436886  0.02391539  0.01971628  0.02578942
#   0.01181878  0.01918919  0.01793692  0.02333185  0.00812938]
# A acurácia na iteração 971 é de 94.89999999999999
# A função custo na iteração 971 é de [-0.          0.0117954   0.02433644  0.02389448  0.01970159  0.02577155
#   0.01181191  0.01917924  0.0179383   0.02331176  0.0081186 ]
# A acurácia na iteração 972 é de 94.89999999999999
# A função custo na iteração 972 é de [-0.          0.01178393  0.02433847  0.02387571  0.01969879  0.02574361
#   0.01179514  0.0191615   0.0179196   0.02328771  0.00811302]
# A acurácia na iteração 973 é de 94.89999999999999
# A função custo na iteração 973 é de [-0.          0.01178144  0.02430208  0.02387356  0.01967305  0.02572421
#   0.01179214  0.01914992  0.01788314  0.02328826  0.00810803]
# A acurácia na iteração 974 é de 94.89999999999999
# A função custo na iteração 974 é de [-0.          0.01176736  0.02430116  0.02384172  0.01967677  0.02569579
#   0.01177507  0.01913223  0.01789399  0.02325485  0.0080955 ]
# A acurácia na iteração 975 é de 94.89999999999999
# A função custo na iteração 975 é de [-0.          0.0117636   0.02426965  0.02384792  0.01964434  0.02567118
#   0.01177202  0.01912017  0.01785099  0.02326092  0.00809215]
# A acurácia na iteração 976 é de 94.89999999999999
# A função custo na iteração 976 é de [-0.          0.01175309  0.02424687  0.02381958  0.01964168  0.02564671
#   0.01176166  0.01910173  0.01786174  0.02323481  0.00808389]
# A acurácia na iteração 977 é de 94.925
# A função custo na iteração 977 é de [-0.          0.01174719  0.02423518  0.02381344  0.01962405  0.02562617
#   0.01175156  0.01908864  0.01782418  0.02322554  0.00807476]
# A acurácia na iteração 978 é de 94.925
# A função custo na iteração 978 é de [-0.          0.01174401  0.02421493  0.02378134  0.01962099  0.02558981
#   0.01174221  0.01906134  0.01782387  0.02322562  0.00806559]
# A acurácia na iteração 979 é de 94.925
# A função custo na iteração 979 é de [-0.          0.01174085  0.02419465  0.02378749  0.01959505  0.02557046
#   0.01173788  0.01905267  0.01778025  0.02321322  0.0080557 ]
# A acurácia na iteração 980 é de 94.925
# A função custo na iteração 980 é de [-0.          0.01173144  0.02417012  0.02375994  0.01959414  0.02554627
#   0.01172894  0.01903141  0.0177764   0.02319717  0.00805135]
# A acurácia na iteração 981 é de 94.925
# A função custo na iteração 981 é de [-0.          0.01172607  0.02415324  0.0237594   0.01957085  0.02552294
#   0.01172127  0.01902044  0.01774165  0.02318772  0.00804313]
# A acurácia na iteração 982 é de 94.925
# A função custo na iteração 982 é de [-0.          0.01171478  0.02414099  0.02372326  0.01957437  0.02550097
#   0.0117081   0.01900096  0.01774755  0.02316034  0.00803443]
# A acurácia na iteração 983 é de 94.925
# A função custo na iteração 983 é de [-0.          0.01171188  0.02411559  0.02373393  0.01954446  0.02547093
#   0.011703    0.01899124  0.01770691  0.02315865  0.00802853]
# A acurácia na iteração 984 é de 94.925
# A função custo na iteração 984 é de [-0.          0.01169868  0.02410755  0.02369308  0.01955396  0.02545255
#   0.01168658  0.01896737  0.0177189   0.02312712  0.00801918]
# A acurácia na iteração 985 é de 94.925
# A função custo na iteração 985 é de [-0.          0.01169395  0.0240792   0.02370607  0.01952318  0.02542821
#   0.01168324  0.01896214  0.01766725  0.02312731  0.00801384]
# A acurácia na iteração 986 é de 94.925
# A função custo na iteração 986 é de [-0.          0.01168473  0.02405701  0.0236816   0.01951732  0.02539221
#   0.01167272  0.01893846  0.01769003  0.02310692  0.00800342]
# A acurácia na iteração 987 é de 94.925
# A função custo na iteração 987 é de [-0.          0.01167841  0.02404345  0.02367399  0.01949875  0.02538767
#   0.0116627   0.01892858  0.01763358  0.02309697  0.00800026]
# A acurácia na iteração 988 é de 94.95
# A função custo na iteração 988 é de [-0.          0.01167106  0.0240108   0.02363951  0.01949212  0.02535457
#   0.01165529  0.01891026  0.01765816  0.02308196  0.00799077]
# A acurácia na iteração 989 é de 94.95
# A função custo na iteração 989 é de [-0.          0.01166216  0.02401093  0.02364497  0.01947363  0.02532972
#   0.01164155  0.01889956  0.01761338  0.02306517  0.00798374]
# A acurácia na iteração 990 é de 94.975
# A função custo na iteração 990 é de [-0.          0.01165164  0.02398774  0.02361788  0.01947156  0.0253114
#   0.01163126  0.0188787   0.01761792  0.02304252  0.00797493]
# A acurácia na iteração 991 é de 94.975
# A função custo na iteração 991 é de [-0.          0.01164878  0.02396696  0.02362842  0.01943976  0.02527812
#   0.01162561  0.01886737  0.01757523  0.02304659  0.00796895]
# A acurácia na iteração 992 é de 94.975
# A função custo na iteração 992 é de [-0.          0.01164007  0.02393644  0.02360299  0.01943692  0.02525183
#   0.01161988  0.01884818  0.01758417  0.02302559  0.00796063]
# A acurácia na iteração 993 é de 95.025
# A função custo na iteração 993 é de [-0.          0.01163076  0.02393557  0.02358591  0.01942701  0.02523636
#   0.01160435  0.01883395  0.01755153  0.02300979  0.00795223]
# A acurácia na iteração 994 é de 95.05
# A função custo na iteração 994 é de [-0.          0.01162362  0.02390702  0.02359032  0.01940706  0.02519847
#   0.01160169  0.01881876  0.01753937  0.02299916  0.00794286]
# A acurácia na iteração 995 é de 95.05
# A função custo na iteração 995 é de [-0.          0.01161467  0.02389639  0.02354951  0.01940771  0.02519239
#   0.01158555  0.01880681  0.01752877  0.02297327  0.00793474]
# A acurácia na iteração 996 é de 95.05
# A função custo na iteração 996 é de [-0.          0.01160839  0.02386636  0.02356609  0.01938103  0.0251472
#   0.01158176  0.01879494  0.01750163  0.02297431  0.0079292 ]
# A acurácia na iteração 997 é de 95.05
# A função custo na iteração 997 é de [-0.          0.01160007  0.02384295  0.02352624  0.01938009  0.02513745
#   0.01157133  0.0187786   0.01750796  0.0229499   0.00791777]
# A acurácia na iteração 998 é de 95.05
# A função custo na iteração 998 é de [-0.          0.01159565  0.02382579  0.0235397   0.01934946  0.02511556
#   0.01156538  0.01876858  0.01745941  0.02294399  0.00791072]
# A acurácia na iteração 999 é de 95.075
# A função custo na iteração 999 é de [-0.          0.01158412  0.02381359  0.0234933   0.01935624  0.02509218
#   0.01155062  0.01874468  0.01748305  0.02291827  0.00789984]
# A acurácia do modelo no conjunto de treino é de 95.075

# %%
for i in range(np.shape(Loss)[1]):
    plt.plot(np.array(Loss).T[i], label = 'J'+str(i+1))

plt.grid(linestyle = ':')
plt.legend()

plt.xlabel('Episódio [-]')
plt.ylabel('Função Custo - Treino [-]')

plt.savefig('Plots/Custo_Treino_Multi.png', format = 'png',dpi = 600, bbox_inches = 'tight')

# %%
for i in range(np.shape(Loss_t)[1]):
    plt.plot(np.array(Loss_t).T[i], label = 'J'+str(i+1))

plt.grid(linestyle = ':')
plt.legend()

plt.xlabel('Episódio [-]')
plt.ylabel('Função Custo - Teste [-]')

plt.savefig('Plots/Custo_Teste_Multi.png', format = 'png',dpi = 600, bbox_inches = 'tight')

# %% [markdown]
# #### Acurácia no conjunto de teste

# %%
np.array(Perf).T[0][-1]
# Out:
# 95.075

# %%
plt.plot(np.array(Perf).T[0], label = 'Treino')
plt.plot(np.array(Perf).T[1], label = 'Teste')

plt.grid(linestyle = ':')
plt.legend()

plt.xlabel('Episódio [-]')
plt.ylabel('Acurácia [\%]')

plt.savefig('Plots/Acurácia_Multi.png', format = 'png',dpi = 600, bbox_inches = 'tight')
